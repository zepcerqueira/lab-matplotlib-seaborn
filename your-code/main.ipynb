# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import squarify

import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go

import plotly.graph_objs as go
from plotly.subplots import make_subplots

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1

sns.scatterplot(x = x, y = y)
plt.show()

# %%
sns.scatterplot(x = x, y = z)
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
data = {'x': x, 'y': y, 'z': z}
var_df = pd.DataFrame(data)

# %%
var_df
# Out:
#      x    y     z
# 0    0    0     0
# 1    1    2     1
# 2    2    4     4
# 3    3    6     9
# 4    4    8    16
# ..  ..  ...   ...
# 95  95  190  9025
# 96  96  192  9216
# 97  97  194  9409
# 98  98  196  9604
# 99  99  198  9801
#
# [100 rows x 3 columns]

# %%
# Method 2

fig = make_subplots(rows=1, cols=3, subplot_titles=("Var. X", "Var. Y", "Var. Z"))
fig.add_trace(go.Scatter(x=var_df["x"], name="Var. X"), row=1, col=1)
fig.add_trace(go.Scatter(x=var_df["y"], name="Var. Y"), row=1, col=2)
fig.add_trace(go.Scatter(x=var_df["z"], name="Var. Z"), row=1, col=3)
fig.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here

fig.update_layout(height=400, width=2000, title_text="Var X, y and Z")

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
y1 = x**2
y2 = np.exp(x)

data_2 = {"x": x, "y": y, "z": z, "y1": y1, "y2": y2}
var_2_df = pd.DataFrame(data_2)

var_2_df
# Out:
#      x    y     z    y1            y2
# 0    0    0     0     0  1.000000e+00
# 1    1    2     1     1  2.718282e+00
# 2    2    4     4     4  7.389056e+00
# 3    3    6     9     9  2.008554e+01
# 4    4    8    16    16  5.459815e+01
# ..  ..  ...   ...   ...           ...
# 95  95  190  9025  9025  1.811239e+41
# 96  96  192  9216  9216  4.923458e+41
# 97  97  194  9409  9409  1.338335e+42
# 98  98  196  9604  9604  3.637971e+42
# 99  99  198  9801  9801  9.889030e+42
#
# [100 rows x 5 columns]

# %%
plt.figure(figsize=(8, 10))
plt.plot(x, y1, label="y1 = x^2", color="blue")

plt.plot(x, y2, label="y2 = e^x", color="red")

plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.yscale('log')
plt.title("Plot - y1 = x^2 and y2 = e^x")
plt.grid(True)
plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
plt.figure(figsize=(8, 10))
plt.plot(x, y1, label="y1 = x^2", color="blue")

plt.plot(x, y2, label="y2 = e^x", color="red")

plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.yscale('log')
plt.title("Plot - y1 = x^2 and y2 = e^x")
plt.grid(True)
plt.legend(['super plot'])
plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here

fitbit_db = pd.read_csv("Fitbit2.csv")
fitbit_db.sample(10)
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 191  2015-11-15            2853   9499      7.06       2            738.000
# 306  2016-03-08            3083  14068     11.26      14            824.000
# 87   2015-08-03             342  15362     11.41      16            683.000
# 224  2015-12-18            2917   9428      7.01      10              1.141
# 215  2015-12-09            3062  10026      7.45      17            803.000
# 10   2015-05-18            2961  11998      8.91      20            936.000
# 146  2015-10-01            2712   7951      5.91      11            667.000
# 103  2015-08-19            3217  12213      9.07       6            421.000
# 259  2016-01-22            3426  14577     10.96       5            519.000
# 248  2016-01-11            3013   9642      7.16      15            758.000
#
#      Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# ...

# %%
fitbit_db.isna().sum()
# Out:
# Date                          0
# Calorie burned                0
# Steps                         0
# Distance                      0
# Floors                        0
# Minutes Sedentary             0
# Minutes Lightly Active        0
# Minutes Fairly Active         0
# Minutes Very Active           0
# Activity Calories             0
# MinutesOfSleep                0
# MinutesOfBeingAwake           0
# NumberOfAwakings              0
# LengthOfRestInMinutes         0
# Distance_miles                0
# Days                          0
# Days_encoded                  0
# Work_or_Weekend               0
# Hours Sleep                   0
# Sleep efficiency              0
# Yesterday_sleep               0
# Yesterday_sleep_efficiency    0
# Months                        0
# Months_encoded                0
# dtype: int64

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here

average_steps_month = fitbit_db.groupby("Months_encoded")["Steps"].mean()
average_steps_month.name = "Average Steps by Month"
average_steps_month = average_steps_month.reset_index()

average_steps_week = fitbit_db.groupby("Days_encoded")["Steps"].mean()
average_steps_week.name = "Average Steps by Week Days"
average_steps_week = average_steps_week.reset_index()

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

fig = make_subplots(rows=1, cols=2, subplot_titles=("Avg. Steps by Month", "Avg. Steps by Week Days"))
fig.add_trace(go.Bar(x=average_steps_month["Average Steps by Month"], name="Average Steps by Month"), row=1, col=1)
fig.add_trace(go.Bar(x=average_steps_week["Average Steps by Week Days"], name="Average Steps by Week Days"), row=1, col=2)

#avg steps is higher on saturday but decreses on sunday. stays arround 10k during weeke days

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
fitbit_db.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %%
# your code here

select_col = ["Minutes Lightly Active", "Minutes Very Active", "Minutes Sedentary"]
for col in select_col:
    plt.figure(figsize=(8, 6))
    plt.barh(fitbit_db[col], fitbit_db.index) 
    plt.title(f"{col} vs Steps")
    plt.xlabel("Steps")
    plt.ylabel(col)
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

titanic_db = pd.read_csv("titanic.csv")
titanic_db.sample(10)
# Out:
#       PassengerId  Survived  Pclass  \
# 309           310       1.0       1
# 918           919       NaN       3
# 801           802       1.0       2
# 520           521       1.0       1
# 28             29       1.0       3
# 97             98       1.0       1
# 1171         1172       NaN       3
# 1292         1293       NaN       2
# 320           321       0.0       3
# 531           532       0.0       3
#
#                                              Name  Gender        Age  SibSp  \
# 309                Francatelli, Miss. Laura Mabel  female  30.000000      0
# 918                             Daher, Mr. Shedid    male  22.500000      0
# 801   Collyer, Mrs. Harvey (Charlotte Annie Tate)  female  31.000000      1
# 520                         Perreault, Miss. Anne  female  30.000000      0
# 28                  O'Dwyer, Miss. Ellen "Nellie"  female  22.581283      0
# 97                Greenfield, Mr. William Bertram    male  23.000000      0
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here

titanic_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Gender       1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        1309 non-null   object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

int_columns = titanic_db.select_dtypes(include=["int64"]).columns
float_columns = titanic_db.select_dtypes(include=["float64"]).columns

  
# display columns
print('\nint64 columns:\n',int_columns)
print('\nfloat64 columns:\n',float_columns)
# Out:
# int64 columns:
#  Index(['PassengerId', 'Pclass', 'SibSp', 'Parch'], dtype='object')
#
# float64 columns:
#  Index(['Survived', 'Age', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
# your code here

object_columns = titanic_db.select_dtypes(include=["object"]).columns
print('\nobject columns:\n',object_columns)
# Out:
# object columns:
#  Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
pd.DataFrame(titanic_db)
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %%
new_titanic_db = titanic_db[["Survived", "Age"]]
new_titanic_db.dropna()
# Out:
#      Survived        Age
# 0         0.0  22.000000
# 1         1.0  38.000000
# 2         1.0  26.000000
# 3         1.0  35.000000
# 4         0.0  35.000000
# ..        ...        ...
# 886       0.0  27.000000
# 887       1.0  19.000000
# 888       0.0  17.914803
# 889       1.0  26.000000
# 890       0.0  32.000000
#
# [891 rows x 2 columns]

# %%
# your code here

new_titanic_db["Survived"] = new_titanic_db["Survived"].replace({1: "Yes", 0: "No"})
survived_counts = new_titanic_db["Survived"].value_counts()
plt.pie(survived_counts, labels=survived_counts.index, autopct="%1.1f%%")
plt.title("Survival Rate by Age")
plt.show()
# Out:
# /var/folders/n7/qn8s75510p5chs7mw2tvcgy80000gp/T/ipykernel_30882/2104475548.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
new_new_titanic_db = titanic_db.dropna()

# %%
plt.figure(figsize=(10, 6))
plt.hist(new_new_titanic_db["Age"], bins=20, edgecolor='k', color='skyblue')
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("The distribution of column - Age")
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
fig, axes = plt.subplots(3, 1, figsize=(10, 10))
#Age with 10 bins
axes[0].hist(new_new_titanic_db["Age"], bins=10)
axes[0].set_title("Dist. of Age with 10 bins")
#Age with 20 bins
axes[1].hist(new_new_titanic_db["Age"], bins=20)
axes[1].set_title("Dist. of Age with 20 bins")
#Age with 50 bins
axes[2].hist(new_new_titanic_db["Age"], bins=50)
axes[2].set_title("Dist. of Age with 50 bins")
# Show the plots
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here

The bin size lets us having a more clear representation of the distribution. 
For example, with 10 and 20 bins, we could assume that for 25 years old, we have a frequency. of 200 and 120, because 
the values between 20 and 30 are all in the same "bin".The bin size can affect the appearance of the distribution. 
With more bins, the distribution will appear more smooth.This is because each bin represents a range of values, and 
the larger the bin size, the more values are included in each bin.Its like a pixels def. of an image.

"""
# Out:
# '\nyour comments here\n\nThe bin size lets us having a more clear representation of the distribution. \nFor example, with 10 and 20 bins, we could assume that for 25 years old, we have a frequency. of 200 and 120, because \nthe values between 20 and 30 are all in the same "bin".The bin size can affect the appearance of the distribution. \nWith more bins, the distribution will appear more smooth.This is because each bin represents a range of values, and \nthe larger the bin size, the more values are included in each bin.Its like a pixels def. of an image.\n\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

sns.displot(new_new_titanic_db, x="Age", binwidth=1, bins=50)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
gender_titanic_db = titanic_db[["Gender"]]
gender_titanic_db.isna().sum()
# Out:
# Gender    0
# dtype: int64

# %%
# Method 1 - matplotlib
# your code here

gender_counts = gender_titanic_db["Gender"].value_counts()
plt.pie(gender_counts, labels=gender_counts.index, autopct="%1.1f%%")
plt.title("Titanic Passengers by Gender")
plt.show()

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

pclass_titanic_db = titanic_db[["Pclass"]]
#pclass_titanic_db.isna().sum()

labels = ["Pclass 1", "Pclass 2", "Pclass 3"]
sizes = [pclass_titanic_db["Pclass"].iloc[0], pclass_titanic_db["Pclass"].iloc[1], pclass_titanic_db["Pclass"].iloc[2]]
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.axis("off")
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

sns.boxplot(x="Age", data=titanic_db)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Box Plot of Age')
plt.show()

# %%
"""
your comments here
For this case, we use boxplot. we can see if the data is symmetric, skewed, can give us the median , the max and 
min and the quartiles.

"""
# Out:
# '\nyour comments here\nFor this case, we use boxplot. we can see if the data is symmetric, skewed, can give us the median , the max and \nmin and the quartiles.\n\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here

The median is set at arround 28, 75% of the population where younger then arround 38, the max value is 80 and the younger was 0.

"""
# Out:
# '\nyour comments here\n\nThe median is set at arround 28, 75% of the population where younger then arround 38, the max value is 80 and the younger was 0.\n\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

sns.kdeplot(titanic_db["Age"])

med_age = titanic_db["Age"].median()
q1 = titanic_db["Age"].quantile(0.25)
q3 = titanic_db["Age"].quantile(0.75)
q4 = titanic_db["Age"].max()
min = titanic_db["Age"].min()


plt.axvline(med_age, color="orange", linestyle="-", label=f"Median Age: {med_age}")
plt.axvline(q1, color="blue", linestyle="-", label=f"Q1: {q1}")
plt.axvline(q3, color="green", linestyle="-", label=f"Q3: {q3}")
plt.axvline(q4, color="purple", linestyle="-", label=f"Q4: {q4}")
plt.axvline(min, color="grey", linestyle="-", label=f"Min.: {min}")

plt.ylabel("Distribution")
plt.legend() 
plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

corr = titanic_db.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# /var/folders/n7/qn8s75510p5chs7mw2tvcgy80000gp/T/ipykernel_30882/2504004338.py:4: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <style type="text/css">
# #T_b40d7_row0_col0, #T_b40d7_row1_col1, #T_b40d7_row2_col2, #T_b40d7_row3_col3, #T_b40d7_row4_col4, #T_b40d7_row5_col5, #T_b40d7_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b40d7_row0_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_b40d7_row0_col2, #T_b40d7_row6_col4 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_b40d7_row0_col3 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_b40d7_row0_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_b40d7_row0_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_b40d7_row0_col6 {
#   background-color: #b9d0f9;
# ...

# %%
# Method 2 - seaborn
# your code here
sns.heatmap(titanic_db.corr(), annot=True)
# Out:
# /var/folders/n7/qn8s75510p5chs7mw2tvcgy80000gp/T/ipykernel_30882/610592439.py:3: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <Axes: >

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
corr_matrix = titanic_db.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
upper
# Out:
# /var/folders/n7/qn8s75510p5chs7mw2tvcgy80000gp/T/ipykernel_30882/3798408025.py:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId          NaN  0.005007  0.038354  0.025325  0.055224  0.008942
# Survived             NaN       NaN  0.338481  0.065376  0.035322  0.081629
# Pclass               NaN       NaN       NaN  0.425965  0.060832  0.018322
# Age                  NaN       NaN       NaN       NaN  0.260706  0.145488
# SibSp                NaN       NaN       NaN       NaN       NaN  0.373587
# Parch                NaN       NaN       NaN       NaN       NaN       NaN
# Fare                 NaN       NaN       NaN       NaN       NaN       NaN
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# ...

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here

Fare and Pclass, but even that is a weak correlation.

"""
# Out:
# '\nyour comments here\n\nFare and Pclass, but even that is a weak correlation.\n\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

plt.figure(figsize=(10, 6))
sns.boxplot(x="Pclass", y="Age", data=titanic_db)
plt.title("Age by Passenger Class")
plt.xlabel("Pclass")
plt.ylabel("Age")
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
titanic_db
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %%
# your code here
import seaborn


#graph = sns.FacetGrid(titanic_db, col="Age", hue="Gender")
#graph.map(plt.scatter, "Age", "Gender", edgecolor="w")
#graph.add_legend()
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 5
#       1 # your code here
#       2 import seaborn
# ----> 5 graph = sns.FacetGrid(titanic_db, col="Age", hue="Gender")
#       6 graph.map(plt.scatter, "Age", "Gender", edgecolor="w")
#       7 graph.add_legend()
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:526, in FacetGrid.__init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws)
#     523 # --- Make the axes look good
#     525 self.set_titles()
# --> 526 self.tight_layout()
#     528 if despine:
#     529     self.despine()
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118, in Grid.tight_layout(self, *args, **kwargs)
# ...
